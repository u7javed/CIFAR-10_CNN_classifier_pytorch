# %%
import torch
import torch.nn as nn
import torchvision
import torchvision.transforms as transforms
import torch.optim as optim
import matplotlib.pyplot as plt
import numpy as np

# %%
#initiate device (CPU or GPU)
if torch.cuda.is_available():
    device = 'cuda:0'
else:
    devuce = 'cpu'

# %% [markdown]
# # Preprocess MNIST Data

# %%
#apply preprocessing transformations of Normalizing and converting datatype to pytorch tensor
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5), (0.5))
])

#load in MNIST train and test dataset
train_dataset = torchvision.datasets.MNIST('data', train=True, transform=transform, download=True)
test_dataset = torchvision.datasets.MNIST('data', train=False, transform=transform, download=True)

# %%
#convert dataset to pytorch dataloader object to iterate through batches
batch_size = 124

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=1)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size, shuffle=True, num_workers=1)

# %%
images_sample, labels_sample = next(iter(train_loader))
print('Format of MNIST images: ',images_sample.size(), ' = format([Batch Size, Color dim, Width, Height])\n')
print('STEP 1: Squish the incoming batch of images to a 1D Tensor with size of first input layer:') 
print(images_sample[2].size(), ' -----> ', images_sample[2].view(images_sample[2].size(0), -1).size())
print('\nNOTE, the squished Tensor is still a 2D tensor but the x dimension is only of length 1, making it')
print('essentially a 1D tensor in the Y-Axis\n')
print('STEP 2: Feed batch of images through the MLP\n')
print('STEP 3: Train the model\n')
print('STEP 4: Test the model\'s accuracy')
# Out:
# Format of MNIST images:  torch.Size([124, 1, 28, 28])  = format([Batch Size, Color dim, Width, Height])
#
# STEP 1: Squish the incoming batch of images to a 1D Tensor with size of first input layer:
# torch.Size([1, 28, 28])  ----->  torch.Size([1, 784])
#
# NOTE, the squished Tensor is still a 2D tensor but the x dimension is only of length 1, making it
# essentially a 1D tensor in the Y-Axis
#
# STEP 2: Feed batch of images through the MLP
#
# STEP 3: Train the model
#
# STEP 4: Test the model's accuracy

# %%
grid_img = torchvision.utils.make_grid(images_sample[:6], nrow=6)
fig, ax = plt.subplots(figsize=(18, 4))
ax.imshow(grid_img.permute(1, 2, 0))
print('Corresponding respective labels: ', labels_sample[:6].tolist())
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Corresponding respective labels:  [1, 7, 1, 9, 6, 0]

# %% [markdown]
# # Define Multi-Layer Perceptron

# %%
#option to choose activation function between relu and tanh (default: relu)
def choose_activation(string):
    if string == 'relu':
        return nn.ReLU()
    elif string == 'tanh':
        return nn.Tanh()

#MLP Model
class Classifier(nn.Module):
    def __init__(self, activation_func='relu'):
        super(Classifier, self).__init__()
        self.activation_func = choose_activation(activation_func)
        self.mlp = nn.Sequential(
            #MNIST Input shape of each MNIST image is [1, 28, 28]
            nn.Dropout(0.4),
            nn.Linear(1*28*28, 500),
            self.activation_func,
            nn.BatchNorm1d(500),     #apply batch norm to improve training

            nn.Dropout(0.4),
            nn.Linear(500, 200),
            self.activation_func,
            nn.BatchNorm1d(200),

            nn.Linear(200, 10), 
            nn.Sigmoid()    #squish between 0 and 1. 0 being not classified and 1 being classified
        )
    def forward(self, input):
        #squish 3D tensor of image to "1D"
        input = input.view(input.size(0), -1)
        input = self.mlp(input) # pass through MLP
        return input

# %% [markdown]
# # Train the model

# %%
mlp = Classifier().to(device) #default relu
loss_func = nn.CrossEntropyLoss().to(device)
optimizer = optim.Adam(mlp.parameters(), lr = 0.001)

# %%
epochs = 100

if device == 'cuda:0':
    print('----> Using GPU\n')
else:
    print('----> Using CPU\n')

min_loss = np.Inf

for epoch in range(epochs):
    train_loss = 0  #keep track of training loss each way
    for images, labels in train_loader:
        mlp.zero_grad() #zero out gradients for training

        outputs = mlp(images.to(device))
        loss = loss_func(outputs, labels.to(device))    #measure loss
        loss.backward()   #compute differential loss dloss/dx
        optimizer.step()    #gradient descent
        train_loss += loss.item()/len(images)

    print('Epoch: {}, Train Loss: {:.4f}\n'.format(   #print training loss at each step
        epoch,
        train_loss
    )) 
    if train_loss < min_loss:   #print lowest loss
        print('     New minimum loss {:.4f} ---> {:.4f}\n'.format(
            min_loss,
            train_loss
        ))

        min_loss = train_loss
        torch.save(mlp.state_dict(), 'best_model.pt')   #save model to file
# Out:
# ----> Using GPU
#
# Epoch: 0, Train Loss: 6.4956
#
#      New minimum loss inf ---> 6.4956
#
# Epoch: 1, Train Loss: 6.0772
#
#      New minimum loss 6.4956 ---> 6.0772
#
# Epoch: 2, Train Loss: 6.0176
#
#      New minimum loss 6.0772 ---> 6.0176
#
# Epoch: 3, Train Loss: 5.9889
#
#      New minimum loss 6.0176 ---> 5.9889
#
# Epoch: 4, Train Loss: 5.9662
#
#      New minimum loss 5.9889 ---> 5.9662
#
# Epoch: 5, Train Loss: 5.9474
#
#      New minimum loss 5.9662 ---> 5.9474
#
# Epoch: 6, Train Loss: 5.9388
#
#      New minimum loss 5.9474 ---> 5.9388
#
# Epoch: 7, Train Loss: 5.9298
#
#      New minimum loss 5.9388 ---> 5.9298
#
# Epoch: 8, Train Loss: 5.9236
#
#      New minimum loss 5.9298 ---> 5.9236
#
# Epoch: 9, Train Loss: 5.9183
#
#      New minimum loss 5.9236 ---> 5.9183
#
# Epoch: 10, Train Loss: 5.9136
#
#      New minimum loss 5.9183 ---> 5.9136
#
# Epoch: 11, Train Loss: 5.9034
#
#      New minimum loss 5.9136 ---> 5.9034
#
# Epoch: 12, Train Loss: 5.9044
#
# Epoch: 13, Train Loss: 5.8952
#
#      New minimum loss 5.9034 ---> 5.8952
#
# Epoch: 14, Train Loss: 5.8995
#
# Epoch: 15, Train Loss: 5.8953
#
# Epoch: 16, Train Loss: 5.8874
#
#      New minimum loss 5.8952 ---> 5.8874
#
# Epoch: 17, Train Loss: 5.8855
#
#      New minimum loss 5.8874 ---> 5.8855
#
# Epoch: 18, Train Loss: 5.8846
#
#      New minimum loss 5.8855 ---> 5.8846
#
# Epoch: 19, Train Loss: 5.8777
#
#      New minimum loss 5.8846 ---> 5.8777
#
# Epoch: 20, Train Loss: 5.8781
#
# Epoch: 21, Train Loss: 5.8749
#
#      New minimum loss 5.8777 ---> 5.8749
#
# Epoch: 22, Train Loss: 5.8732
#
#      New minimum loss 5.8749 ---> 5.8732
#
# Epoch: 23, Train Loss: 5.8708
#
#      New minimum loss 5.8732 ---> 5.8708
#
# Epoch: 24, Train Loss: 5.8722
#
# Epoch: 25, Train Loss: 5.8703
#
#      New minimum loss 5.8708 ---> 5.8703
#
# Epoch: 26, Train Loss: 5.8674
#
#      New minimum loss 5.8703 ---> 5.8674
#
# Epoch: 27, Train Loss: 5.8663
#
#      New minimum loss 5.8674 ---> 5.8663
#
# Epoch: 28, Train Loss: 5.8630
#
#      New minimum loss 5.8663 ---> 5.8630
#
# Epoch: 29, Train Loss: 5.8616
#
#      New minimum loss 5.8630 ---> 5.8616
#
# Epoch: 30, Train Loss: 5.8621
#
# Epoch: 31, Train Loss: 5.8655
#
# Epoch: 32, Train Loss: 5.8570
#
#      New minimum loss 5.8616 ---> 5.8570
#
# Epoch: 33, Train Loss: 5.8571
#
# Epoch: 34, Train Loss: 5.8579
#
# Epoch: 35, Train Loss: 5.8536
#
#      New minimum loss 5.8570 ---> 5.8536
#
# Epoch: 36, Train Loss: 5.8537
#
# Epoch: 37, Train Loss: 5.8469
#
#      New minimum loss 5.8536 ---> 5.8469
#
# Epoch: 38, Train Loss: 5.8516
#
# Epoch: 39, Train Loss: 5.8530
#
# Epoch: 40, Train Loss: 5.8501
#
# Epoch: 41, Train Loss: 5.8484
#
# Epoch: 42, Train Loss: 5.8465
#
#      New minimum loss 5.8469 ---> 5.8465
#
# Epoch: 43, Train Loss: 5.8459
#
#      New minimum loss 5.8465 ---> 5.8459
#
# Epoch: 44, Train Loss: 5.8453
#
#      New minimum loss 5.8459 ---> 5.8453
#
# Epoch: 45, Train Loss: 5.8477
#
# Epoch: 46, Train Loss: 5.8444
#
#      New minimum loss 5.8453 ---> 5.8444
#
# Epoch: 47, Train Loss: 5.8453
#
# Epoch: 48, Train Loss: 5.8434
#
#      New minimum loss 5.8444 ---> 5.8434
#
# Epoch: 49, Train Loss: 5.8406
#
#      New minimum loss 5.8434 ---> 5.8406
#
# Epoch: 50, Train Loss: 5.8427
#
# Epoch: 51, Train Loss: 5.8391
#
#      New minimum loss 5.8406 ---> 5.8391
#
# Epoch: 52, Train Loss: 5.8388
#
#      New minimum loss 5.8391 ---> 5.8388
#
# Epoch: 53, Train Loss: 5.8425
#
# Epoch: 54, Train Loss: 5.8410
#
# Epoch: 55, Train Loss: 5.8396
#
# Epoch: 56, Train Loss: 5.8426
#
# Epoch: 57, Train Loss: 5.8359
#
#      New minimum loss 5.8388 ---> 5.8359
#
# Epoch: 58, Train Loss: 5.8379
#
# Epoch: 59, Train Loss: 5.8377
#
# Epoch: 60, Train Loss: 5.8365
#
# Epoch: 61, Train Loss: 5.8358
#
#      New minimum loss 5.8359 ---> 5.8358
#
# Epoch: 62, Train Loss: 5.8330
#
#      New minimum loss 5.8358 ---> 5.8330
#
# Epoch: 63, Train Loss: 5.8344
#
# Epoch: 64, Train Loss: 5.8337
#
# Epoch: 65, Train Loss: 5.8322
#
#      New minimum loss 5.8330 ---> 5.8322
#
# Epoch: 66, Train Loss: 5.8340
#
# Epoch: 67, Train Loss: 5.8308
#
#      New minimum loss 5.8322 ---> 5.8308
#
# Epoch: 68, Train Loss: 5.8320
#
# Epoch: 69, Train Loss: 5.8324
#
# Epoch: 70, Train Loss: 5.8318
#
# Epoch: 71, Train Loss: 5.8297
#
#      New minimum loss 5.8308 ---> 5.8297
#
# Epoch: 72, Train Loss: 5.8308
#
# Epoch: 73, Train Loss: 5.8297
#
# Epoch: 74, Train Loss: 5.8303
#
# Epoch: 75, Train Loss: 5.8291
#
#      New minimum loss 5.8297 ---> 5.8291
#
# Epoch: 76, Train Loss: 5.8299
#
# Epoch: 77, Train Loss: 5.8277
#
#      New minimum loss 5.8291 ---> 5.8277
#
# Epoch: 78, Train Loss: 5.8288
#
# Epoch: 79, Train Loss: 5.8275
#
#      New minimum loss 5.8277 ---> 5.8275
#
# Epoch: 80, Train Loss: 5.8282
#
# Epoch: 81, Train Loss: 5.8282
#
# Epoch: 82, Train Loss: 5.8253
#
#      New minimum loss 5.8275 ---> 5.8253
#
# Epoch: 83, Train Loss: 5.8284
#
# Epoch: 84, Train Loss: 5.8240
#
#      New minimum loss 5.8253 ---> 5.8240
#
# Epoch: 85, Train Loss: 5.8244
#
# Epoch: 86, Train Loss: 5.8279
#
# Epoch: 87, Train Loss: 5.8259
#
# Epoch: 88, Train Loss: 5.8238
#
#      New minimum loss 5.8240 ---> 5.8238
#
# Epoch: 89, Train Loss: 5.8248
#
# Epoch: 90, Train Loss: 5.8270
#
# Epoch: 91, Train Loss: 5.8250
#
# Epoch: 92, Train Loss: 5.8232
#
#      New minimum loss 5.8238 ---> 5.8232
#
# Epoch: 93, Train Loss: 5.8227
#
#      New minimum loss 5.8232 ---> 5.8227
#
# Epoch: 94, Train Loss: 5.8232
#
# Epoch: 95, Train Loss: 5.8247
#
# Epoch: 96, Train Loss: 5.8245
#
# Epoch: 97, Train Loss: 5.8223
#
#      New minimum loss 5.8227 ---> 5.8223
#
# Epoch: 98, Train Loss: 5.8244
#
# Epoch: 99, Train Loss: 5.8222
#
#      New minimum loss 5.8223 ---> 5.8222

# %% [markdown]
# # Load and Test Model

# %%
model = Classifier().to(device)
model.load_state_dict(torch.load('best_model.pt'))    #load model
print('Model Loaded: ')
print(model)
# Out:
# Model Loaded:
# Classifier(
#   (activation_func): ReLU()
#   (mlp): Sequential(
#     (0): Dropout(p=0.4, inplace=False)
#     (1): Linear(in_features=784, out_features=500, bias=True)
#     (2): ReLU()
#     (3): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (4): Dropout(p=0.4, inplace=False)
#     (5): Linear(in_features=500, out_features=200, bias=True)
#     (6): ReLU()
#     (7): BatchNorm1d(200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (8): Linear(in_features=200, out_features=10, bias=True)
#     (9): Sigmoid()
#   )
# )

# %%
#make array of 0 with length of the # of unique labels
#each index will correspond to the score of that given index number (0-9) in mnist dataset
right = np.zeros((10), dtype=int)   
wrong = np.zeros((10), dtype=int)

for images, labels in test_loader:
    outputs = model(images.to(device))

    for i in range(len(images)):
        if(torch.argmax(outputs[i]) == labels[i]).tolist(): #check if classification is equal to corresponding label
            right[labels[i]] += 1
        else:
            wrong[labels[i]] += 1
    
for i in range(len(right)):
    print('Accuracy of {}: {:.4f}'.format(
        i,
        right[i]/(right[i] + wrong[i])
    ))
print('Mean Accuracy of model: {:.4f}'.format(
    sum(right)/(sum(right) + sum(wrong))
))
# Out:
# Accuracy of 0: 0.9776
# Accuracy of 1: 0.9824
# Accuracy of 2: 0.9564
# Accuracy of 3: 0.9525
# Accuracy of 4: 0.9338
# Accuracy of 5: 0.9496
# Accuracy of 6: 0.9760
# Accuracy of 7: 0.9465
# Accuracy of 8: 0.9517
# Accuracy of 9: 0.9514
# Mean Accuracy of model: 0.9581

# %% [markdown]
# # Visualizing Prediction

# %%
images, labels = next(iter(test_loader))
output_test = model(images.to('cuda'))
output_list = []
for i in range(6):
    output_list.append([torch.argmax(output_test[i]).tolist()])
gri_img = torchvision.utils.make_grid(images[:6], nrow=6)
fig, axi = plt.subplots(figsize=(18, 4))
axi.imshow(gri_img.permute(1, 2, 0))
print('Corresponding Classification Results: ', output_list)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Corresponding Classification Results:  [[7], [0], [4], [7], [8], [5]]
